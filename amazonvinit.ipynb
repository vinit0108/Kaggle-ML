# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
train=pd.read_csv("Train.csv")
test=pd.read_csv("Test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-cbc052b11cdc> in <module>
# ----> 1 train=pd.read_csv("Train.csv")
#       2 test=pd.read_csv("Test.csv")
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
X=train.iloc[:,:-2]
X.drop('EmpID',axis=1,inplace=True)
X
# Out:
#        EmpName LanguageOfCommunication  Age  Gender JobProfileIDApplyingFor  \
# 0         John                 English   35    Male                 JR85289
# 1      William                 English   26    Male                 JR87525
# 2        James                 English   36  Female                 JR87525
# 3      Charles                 English   29  Female                 JR87525
# 4       George                 English   25    Male                 JR70175
# ...        ...                     ...  ...     ...                     ...
# 13640   Perley                 English   25  Female                 JR87525
# 13641  Randall                  Native   29   Other                 JR87525
# 13642  Raphael                   Hindi   37    Male                 JR88873
# 13643     Reed                   Hindi   24    Male                 JR87525
# 13644   Shelby                 English   35    Male                 JR87525
#
# ...

# %%
y1=train.iloc[:,-1]
y1
# Out:
# 0        95.40
# 1        67.09
# 2        91.26
# 3        72.29
# 4        86.34
#          ...
# 13640    93.65
# 13641    52.90
# 13642    61.46
# 13643    93.64
# 13644    93.52
# Name: FitmentPercent, Length: 13645, dtype: float64

# %%
y2=train.iloc[:,-2:-1]
y2
# Out:
#       BiasInfluentialFactor
# 0          YearsOfExperince
# 1                       NaN
# 2                    Gender
# 3                    Gender
# 4              DegreeBranch
# ...                     ...
# 13640                Gender
# 13641                   NaN
# 13642    CurrentCompanyType
# 13643              EmpScore
# 13644      YearsOfExperince
#
# [13645 rows x 1 columns]

# %%
X_test=test.iloc[:,:]
X_test.drop('EmpID',axis=1,inplace=True)
X_test
# Out:
#         EmpName LanguageOfCommunication  Age  Gender JobProfileIDApplyingFor  \
# 0          Theo                  Native   35    Male                 JR85289
# 1        Vernie                 English   35    Male                 JR85289
# 2       Wendell                 English   28    Male                 JR87525
# 3          West                   Hindi   37    Male                 JR87525
# 4        Alford                   Hindi   36  Female                 JR85289
# ...         ...                     ...  ...     ...                     ...
# 8740       Matt                 English   26  Female                 JR85289
# 8741  Salvatore                   Hindi   27    Male                 JR85289
# 8742     Adrian                 English   27    Male                 JR85289
# 8743    Ambrose                 English   33    Male                 JR79193
# 8744     Arther                  Native   26   Other                 JR89890
#
# ...

# %%
X.drop('LanguageOfCommunication',axis=1,inplace=True)
X.drop('GraduatingInstitute',axis=1,inplace=True)
X.drop('Age',axis=1,inplace=True)
X.drop('MartialStatus',axis=1,inplace=True)
X.drop('CurrentCTC',axis=1,inplace=True)
X.drop('ExpectedCTC',axis=1,inplace=True)
X.drop('GraduationYear',axis=1,inplace=True)
X.drop('TotalLeavesTaken',axis=1,inplace=True)
X.drop('DepartmentInCompany',axis=1,inplace=True)
X.drop('CurrentDesignation',axis=1,inplace=True)

X.drop('EmpName',axis=1,inplace=True)
X.drop('JobProfileIDApplyingFor',axis=1,inplace=True)

# %%
X_test.drop('LanguageOfCommunication',axis=1,inplace=True)
X_test.drop('GraduatingInstitute',axis=1,inplace=True)
X_test.drop('Age',axis=1,inplace=True)
X_test.drop('MartialStatus',axis=1,inplace=True)
X_test.drop('CurrentCTC',axis=1,inplace=True)
X_test.drop('ExpectedCTC',axis=1,inplace=True)
X_test.drop('GraduationYear',axis=1,inplace=True)
X_test.drop('TotalLeavesTaken',axis=1,inplace=True)
X_test.drop('DepartmentInCompany',axis=1,inplace=True)
X_test.drop('CurrentDesignation',axis=1,inplace=True)

X_test.drop('EmpName',axis=1,inplace=True)
X_test.drop('JobProfileIDApplyingFor',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['Gender']=le.fit_transform(X['Gender'].astype(str))
X['HighestDegree']=le.fit_transform(X['HighestDegree'].astype(str))
X['DegreeBranch']=le.fit_transform(X['HighestDegree'].astype(str))
X['CurrentCompanyType']=le.fit_transform(X['HighestDegree'].astype(str))

#X['customer_id']=le.fit_transform(X['customer_id'].astype(str))
X
# Out:
#        Gender  HighestDegree  DegreeBranch  LatestDegreeCGPA  \
# 0           1              0             0                 7
# 1           1              0             0                 7
# 2           0              7             7                 6
# 3           0              1             1                 5
# 4           1              2             2                 8
# ...       ...            ...           ...               ...
# 13640       0              3             3                 7
# 13641       2              2             2                 7
# 13642       1              4             4                 8
# 13643       1              0             0                 4
# 13644       1              0             0                 7
#
#        YearsOfExperince  EmpScore  CurrentCompanyType
# 0                    12         5                   0
# 1                     3         5                   0
# 2                     6         5                   7
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X_test['Gender']=le.fit_transform(X_test['Gender'].astype(str))
X_test['HighestDegree']=le.fit_transform(X_test['HighestDegree'].astype(str))
X_test['DegreeBranch']=le.fit_transform(X_test['HighestDegree'].astype(str))
X_test['CurrentCompanyType']=le.fit_transform(X_test['HighestDegree'].astype(str))

#X['customer_id']=le.fit_transform(X['customer_id'].astype(str))
X_test
# Out:
#       Gender  HighestDegree  DegreeBranch  LatestDegreeCGPA  YearsOfExperince  \
# 0          1              7             7                 5                 5
# 1          1              0             0                 9                12
# 2          1              4             4                 9                 2
# 3          1              6             6                 8                11
# 4          0              7             7                 7                 6
# ...      ...            ...           ...               ...               ...
# 8740       0              0             0                10                 3
# 8741       1              6             6                10                 1
# 8742       1              0             0                 7                 4
# 8743       1              6             6                 7                 7
# 8744       2              2             2                 9                 3
#
# ...

# %%
y2=le.fit_transform(y2.astype(str))

y2
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# array([8, 9, 4, ..., 0, 2, 8])

# %%
#y2.fillna(5, inplace=True)

# %% [markdown]
# from sklearn.svm import SVC
# svc=SVC(kernel='poly',degree=3)
# svc.fit(X,y2)
# print(svc.score(X,y2))

# %%
from sklearn.svm import SVC
svc=SVC(kernel='poly',degree=3)
svc.fit(X,y2)
print(svc.score(X,y2))
# Out:
# 0.5262000732869183

# %%
y_predSVC=svc.predict(X_test)
y_predSVC = le.inverse_transform(y_predSVC)
sample = pd.read_csv("Test.csv")
sample['BiasInfluentialFactor'] = y_predSVC
#sample.drop(["customer_visit_score","customer_product_search_score","customer_ctr_score","customer_stay_score","customer_frequency_score",
 #            "customer_product_variation_score","customer_order_score","customer_affinity_score","customer_active_segment","X1"], axis = 1, inplace = True) 
sample.drop(['EmpName', 'LanguageOfCommunication', 'Age', 'Gender','JobProfileIDApplyingFor', 'HighestDegree', 'DegreeBranch',
       'GraduatingInstitute', 'LatestDegreeCGPA', 'YearsOfExperince',
       'GraduationYear', 'CurrentCTC', 'ExpectedCTC', 'MartialStatus',
       'EmpScore', 'CurrentDesignation', 'CurrentCompanyType',
       'DepartmentInCompany', 'TotalLeavesTaken'], axis = 1, inplace = True) 



sample.to_csv('Re.csv', header=True, index=False)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y1)
# Out:
# LinearRegression()

# %%
y_predSVC=lin_reg.predict(X_test)
sample = pd.read_csv("Re.csv")
sample['FitmentPercent'] = y_predSVC

sample.to_csv('Predictions.csv', header=True, index=False)
